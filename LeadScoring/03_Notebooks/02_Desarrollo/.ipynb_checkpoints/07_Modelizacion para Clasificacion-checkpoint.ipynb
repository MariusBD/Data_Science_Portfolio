# %% [markdown]
# # MODELIZACIÓN PARA CLASIFICACIÓN

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.pipeline import Pipeline

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report

from sklearn.metrics import plot_precision_recall_curve
import scikitplot as skplt
from yellowbrick.classifier import discrimination_threshold

#Autocompletar rápido
# %config IPCompleter.greedy=True

#Desactivar la notación científica
pd.options.display.float_format = '{:.2f}'.format

#Desactivar los warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %%
ruta_proyecto = 'C:/Users/Marius/EstructuraDirectorio/03_MACHINE_LEARNING/06_CASOS/01_LEADSCORING'

nombre_x = 'x_preseleccionado.pickle'
nombre_y = 'y_preseleccionado.pickle'

x = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_x)
y = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_y)

# %% [markdown]
# ## MODELIZAR

# %% [markdown]
# ### Reservar el dataset de validacion

# %%
train_x,val_x,train_y,val_y = train_test_split(x,y,test_size=0.3)

# %% [markdown]
# ### Crear el pipe y el diccionario de algorimos, parámetros y valores a testar

# %%
pipe = Pipeline([('algoritmo',RandomForestClassifier())])

grid = [{'algoritmo': [LogisticRegression()],
         'algoritmo__n_jobs': [-1],
         'algoritmo__solver': ['saga'],
         'algoritmo__penalty': ['elasticnet', 'l1', 'l2', 'none'],
         'algoritmo__C': [0,0.25,0.5,0.75,1]}
       ]

# %% [markdown]
# ### Optimizar los hiper parámetros

# %% [markdown]
# ####  Con grid search

# %%
grid_search = GridSearchCV(estimator= pipe, 
                           param_grid = grid, 
                           cv = 3, 
                           scoring = 'roc_auc',
                           verbose = 0,
                           n_jobs = -1)

modelo = grid_search.fit(train_x,train_y)

pd.DataFrame(grid_search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 7            0.07          0.02             0.00            0.00
# 15           0.09          0.01             0.00            0.00
# 3            0.18          0.09             0.05            0.03
# 11           0.25          0.06             0.01            0.00
# 19           0.07          0.01             0.01            0.00
# 17           0.08          0.01             0.01            0.01
# 13           0.20          0.07             0.01            0.00
# 9            0.12          0.03             0.00            0.00
# 18           0.08          0.00             0.00            0.00
# 14           0.07          0.01             0.00            0.00
# 5            0.24          0.08             0.01            0.01
# 10           0.20          0.04             0.00            0.00
# 6            0.07          0.03             0.00            0.00
# 8            0.00          0.00             0.00            0.00
# 12           0.00          0.00             0.00            0.00
# 4            0.00          0.00             0.00            0.00
# 2            0.07          0.03             0.00            0.00
# 16           0.00          0.00             0.00            0.00
# 1            0.13          0.06             0.00            0.00
# 0            0.00          0.00             0.00            0.00
#
#                                       param_algoritmo param_algoritmo__C  \
# 7   LogisticRegression(C=0.25, n_jobs=-1, penalty=...               0.25
# 15  LogisticRegression(C=0.25, n_jobs=-1, penalty=...               0.75
# 3   LogisticRegression(C=0.25, n_jobs=-1, penalty=...                  0
# 11  LogisticRegression(C=0.25, n_jobs=-1, penalty=...               0.50
# 19  LogisticRegression(C=0.25, n_jobs=-1, penalty=...                  1
# 17  LogisticRegression(C=0.25, n_jobs=-1, penalty=...                  1
# 13  LogisticRegression(C=0.25, n_jobs=-1, penalty=...               0.75
# 9   LogisticRegression(C=0.25, n_jobs=-1, penalty=...               0.50
# 18  LogisticRegression(C=0.25, n_jobs=-1, penalty=...                  1
# 14  LogisticRegression(C=0.25, n_jobs=-1, penalty=...               0.75
# 5   LogisticRegression(C=0.25, n_jobs=-1, penalty=...               0.25
# 10  LogisticRegression(C=0.25, n_jobs=-1, penalty=...               0.50
# 6   LogisticRegression(C=0.25, n_jobs=-1, penalty=...               0.25
# 8   LogisticRegression(C=0.25, n_jobs=-1, penalty=...               0.50
# 12  LogisticRegression(C=0.25, n_jobs=-1, penalty=...               0.75
# 4   LogisticRegression(C=0.25, n_jobs=-1, penalty=...               0.25
# 2   LogisticRegression(C=0.25, n_jobs=-1, penalty=...                  0
# 16  LogisticRegression(C=0.25, n_jobs=-1, penalty=...                  1
# 1   LogisticRegression(C=0.25, n_jobs=-1, penalty=...                  0
# 0   LogisticRegression(C=0.25, n_jobs=-1, penalty=...                  0
#
#    param_algoritmo__n_jobs param_algoritmo__penalty param_algoritmo__solver  \
# 7                       -1                     none                    saga
# 15                      -1                     none                    saga
# 3                       -1                     none                    saga
# 11                      -1                     none                    saga
# 19                      -1                     none                    saga
# 17                      -1                       l1                    saga
# 13                      -1                       l1                    saga
# 9                       -1                       l1                    saga
# 18                      -1                       l2                    saga
# 14                      -1                       l2                    saga
# 5                       -1                       l1                    saga
# 10                      -1                       l2                    saga
# 6                       -1                       l2                    saga
# 8                       -1               elasticnet                    saga
# 12                      -1               elasticnet                    saga
# 4                       -1               elasticnet                    saga
# 2                       -1                       l2                    saga
# 16                      -1               elasticnet                    saga
# 1                       -1                       l1                    saga
# 0                       -1               elasticnet                    saga
#
#                                                params  split0_test_score  \
# 7   {'algoritmo': LogisticRegression(C=0.25, n_job...               0.88
# 15  {'algoritmo': LogisticRegression(C=0.25, n_job...               0.88
# 3   {'algoritmo': LogisticRegression(C=0.25, n_job...               0.88
# 11  {'algoritmo': LogisticRegression(C=0.25, n_job...               0.88
# 19  {'algoritmo': LogisticRegression(C=0.25, n_job...               0.88
# 17  {'algoritmo': LogisticRegression(C=0.25, n_job...               0.88
# 13  {'algoritmo': LogisticRegression(C=0.25, n_job...               0.87
# 9   {'algoritmo': LogisticRegression(C=0.25, n_job...               0.87
# 18  {'algoritmo': LogisticRegression(C=0.25, n_job...               0.87
# 14  {'algoritmo': LogisticRegression(C=0.25, n_job...               0.87
# 5   {'algoritmo': LogisticRegression(C=0.25, n_job...               0.87
# 10  {'algoritmo': LogisticRegression(C=0.25, n_job...               0.87
# 6   {'algoritmo': LogisticRegression(C=0.25, n_job...               0.87
# 8   {'algoritmo': LogisticRegression(C=0.25, n_job...                NaN
# 12  {'algoritmo': LogisticRegression(C=0.25, n_job...                NaN
# 4   {'algoritmo': LogisticRegression(C=0.25, n_job...                NaN
# 2   {'algoritmo': LogisticRegression(C=0.25, n_job...                NaN
# 16  {'algoritmo': LogisticRegression(C=0.25, n_job...                NaN
# 1   {'algoritmo': LogisticRegression(C=0.25, n_job...                NaN
# 0   {'algoritmo': LogisticRegression(C=0.25, n_job...                NaN
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 7                0.88               0.86             0.87            0.01
# 15               0.88               0.86             0.87            0.01
# 3                0.88               0.86             0.87            0.01
# 11               0.88               0.86             0.87            0.01
# 19               0.88               0.86             0.87            0.01
# 17               0.88               0.86             0.87            0.01
# 13               0.88               0.86             0.87            0.01
# 9                0.88               0.85             0.87            0.01
# 18               0.88               0.85             0.87            0.01
# 14               0.88               0.85             0.87            0.01
# 5                0.88               0.85             0.87            0.01
# 10               0.88               0.85             0.87            0.01
# 6                0.87               0.85             0.86            0.01
# 8                 NaN                NaN              NaN             NaN
# 12                NaN                NaN              NaN             NaN
# 4                 NaN                NaN              NaN             NaN
# 2                 NaN                NaN              NaN             NaN
# 16                NaN                NaN              NaN             NaN
# 1                 NaN                NaN              NaN             NaN
# 0                 NaN                NaN              NaN             NaN
#
#     rank_test_score
# 7                 1
# 15                2
# 3                 3
# 11                4
# 19                5
# 17                6
# 13                7
# 9                 8
# 18                9
# 14               10
# 5                11
# 10               12
# 6                13
# 8                14
# 12               15
# 4                16
# 2                17
# 16               18
# 1                19
# 0                20

# %% [markdown]
# ####  Con random search

# %%
#bajarle el n_iter si tarda mucho tiempo
# random_search = RandomizedSearchCV(estimator = pipe,
#                                    param_distributions = grid, 
#                                    n_iter = 5, 
#                                    cv = 3, 
#                                    scoring = 'roc_auc', 
#                                    verbose = 0,
#                                    n_jobs = -1)

# modelo = random_search.fit(train_x,train_y)

# pd.DataFrame(random_search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 3           0.38          0.00             0.01            0.00
# 1           0.44          0.01             0.01            0.00
# 2           3.75          0.08             0.03            0.00
# 4           2.77          0.52             0.02            0.00
# 0           2.14          0.05             0.02            0.00
#
#   param_algoritmo__verbosity param_algoritmo__reg_lambda  \
# 3                          0                           1
# 1                          0                        0.10
# 2                          0                           1
# 4                          0                           1
# 0                          0                        0.01
#
#   param_algoritmo__reg_alpha param_algoritmo__n_jobs  \
# 3                       0.10                      -1
# 1                          0                      -1
# 2                       0.10                      -1
# 4                          0                      -1
# 0                          0                      -1
#
#   param_algoritmo__n_estimators param_algoritmo__max_depth  \
# 3                           100                         10
# 1                           100                         10
# 2                          1000                         10
# 4                           500                         20
# 0                          1000                          5
#
#   param_algoritmo__learning_rate  \
# 3                           0.05
# 1                           0.03
# 2                           0.03
# 4                           0.05
# 0                           0.10
#
#                                      param_algoritmo  \
# 3  XGBClassifier(base_score=None, booster=None, c...
# 1  XGBClassifier(base_score=None, booster=None, c...
# 2  XGBClassifier(base_score=None, booster=None, c...
# 4  XGBClassifier(base_score=None, booster=None, c...
# 0  XGBClassifier(base_score=None, booster=None, c...
#
#                                               params  split0_test_score  \
# 3  {'algoritmo__verbosity': 0, 'algoritmo__reg_la...               0.78
# 1  {'algoritmo__verbosity': 0, 'algoritmo__reg_la...               0.78
# 2  {'algoritmo__verbosity': 0, 'algoritmo__reg_la...               0.77
# 4  {'algoritmo__verbosity': 0, 'algoritmo__reg_la...               0.77
# 0  {'algoritmo__verbosity': 0, 'algoritmo__reg_la...               0.77
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 3               0.77               0.78             0.78            0.00
# 1               0.77               0.78             0.78            0.00
# 2               0.77               0.78             0.77            0.00
# 4               0.77               0.77             0.77            0.00
# 0               0.77               0.77             0.77            0.00
#
#    rank_test_score
# 3                1
# 1                2
# 2                3
# 4                4
# 0                5

# %% [markdown]
# ## EVALUAR

# %% [markdown]
# ### Predecir sobre validación

# %%
pred = modelo.best_estimator_.predict_proba(val_x)[:, 1]

# %% [markdown]
# ### Evaluar sobre validación

# %%
roc_auc_score(val_y, pred)
# Out:
# 0.8722180711960295

# %% [markdown]
# ### Examinar el mejor modelo

# %%
modelo.best_estimator_
# Out:
# Pipeline(steps=[('algoritmo',
#                  LogisticRegression(C=0.25, n_jobs=-1, penalty='none',
#                                     solver='saga'))])

# %%
#buscamos los mejores coeficientes
modelo.best_estimator_.named_steps.algoritmo.coef_
# Out:
# array([[ 4.42524402,  7.84106854,  0.98832189,  1.4724142 ,  2.55592656,
#          2.13009643, -2.78546673, -0.34450943, -1.36945027, -1.44251204,
#          2.5153308 ,  0.34982074, -0.62776446, -1.28369927, -0.0814706 ]])

# %%
#sacamos nombres de los coeficientes mas predictivos
modelo.best_estimator_.named_steps.algoritmo.feature_names_in_
# Out:
# array(['tiempo_en_site_total_mms', 'score_actividad_mms',
#        'ult_actividad_SMS Sent', 'score_perfil_mms', 'visitas_total_mms',
#        'ocupacion_Working Professional', 'paginas_vistas_visita_mms',
#        'ambito_Select', 'ult_actividad_Converted to Lead',
#        'ult_actividad_Chat Conversation', 'origen_Lead Add Form',
#        'descarga_lm_No', 'ocupacion_Unemployed',
#        'ult_actividad_Page Visited on Website',
#        'ult_actividad_Email Opened'], dtype=object)

# %%
pd.DataFrame(data=modelo.best_estimator_.named_steps.algoritmo.coef_,
            columns = modelo.best_estimator_.named_steps.algoritmo.feature_names_in_).unstack()\
    .sort_values(ascending=False)

'''En la parte de examinar hemos mirado que variables resultan mas predictivas y lo que resulta mas predictivo es 
el score_actividad tiempo_en_site_total_mms, paginas_vistas_visita_mms'''
# Out:
# score_actividad_mms                    0    7.84
# tiempo_en_site_total_mms               0    4.43
# visitas_total_mms                      0    2.56
# origen_Lead Add Form                   0    2.52
# ocupacion_Working Professional         0    2.13
# score_perfil_mms                       0    1.47
# ult_actividad_SMS Sent                 0    0.99
# descarga_lm_No                         0    0.35
# ult_actividad_Email Opened             0   -0.08
# ambito_Select                          0   -0.34
# ocupacion_Unemployed                   0   -0.63
# ult_actividad_Page Visited on Website  0   -1.28
# ult_actividad_Converted to Lead        0   -1.37
# ult_actividad_Chat Conversation        0   -1.44
# paginas_vistas_visita_mms              0   -2.79
# dtype: float64

# %% [markdown]
# ## REPORTING DEL MODELO

# %% [markdown]
# ### Gain Chart

# %%
fig, ax = plt.subplots()

skplt.metrics.plot_cumulative_gain(val_y, modelo.best_estimator_.predict_proba(val_x), ax=ax) 


del ax.lines[0]                 
plt.legend(labels = ['Modelo','Aleatoria']);

# %% [markdown]
# ### Lift Chart

# %%
fig, ax = plt.subplots()

skplt.metrics.plot_lift_curve(val_y, modelo.best_estimator_.predict_proba(val_x), ax=ax) 


del ax.lines[0]                 
plt.legend(labels = ['Modelo','Aleatoria']);

# %% [markdown]
# ### ROC Chart

# %%
fig, ax = plt.subplots()

skplt.metrics.plot_roc(val_y, modelo.best_estimator_.predict_proba(val_x), ax=ax) 


del ax.lines[0]                 
del ax.lines[1] 
del ax.lines[1]
plt.legend(labels = ['Modelo','Aleatoria']);
